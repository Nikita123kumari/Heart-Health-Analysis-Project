# %% [markdown]
# ## 1.  Import datasets

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data=pd.read_csv('heart.csv')

# %% [markdown]
# # Information of dataset
# 1. age
# 2. sex
# 3. chest pain type (4 values)
# 4. resting blood pressure
# 5. serum cholestoral in mg/dl
# 6. fasting blood sugar > 120 mg/dl
# 7. resting electrocardiographic results (values 0,1,2)
# 8. maximum heart rate achieved
# 9. exercise induced angina
# 10. oldpeak = ST depression induced by exercise relative to rest
# 11. the slope of the peak exercise ST segment
# 12. number of major vessels (0-3) colored by flourosopy
# 13. thal: 0 = normal; 1 = fixed defect; 2 = reversable defect
# 14. The names and social security numbers of the patients were 15. recently removed from the database, replaced with dummy values.

# %% [markdown]
# ## 2. Display Top 5 Rows of dataset

# %%
data.head(5)
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   52    1   0       125   212    0        1      168      0      1.0      2
# 1   53    1   0       140   203    1        0      155      1      3.1      0
# 2   70    1   0       145   174    0        1      125      1      2.6      0
# 3   61    1   0       148   203    0        1      161      0      0.0      2
# 4   62    0   0       138   294    1        1      106      0      1.9      1
#
#    ca  thal  target
# 0   2     3       0
# 1   0     3       0
# 2   0     3       0
# 3   1     3       0
# 4   3     2       0

# %% [markdown]
# # 3. Last 5 rows of dataset

# %%
data.tail()
# Out:
#       age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 1020   59    1   1       140   221    0        1      164      1      0.0
# 1021   60    1   0       125   258    0        0      141      1      2.8
# 1022   47    1   0       110   275    0        0      118      1      1.0
# 1023   50    0   0       110   254    0        0      159      0      0.0
# 1024   54    1   0       120   188    0        1      113      0      1.4
#
#       slope  ca  thal  target
# 1020      2   0     2       1
# 1021      1   1     3       0
# 1022      1   1     2       0
# 1023      2   0     2       1
# 1024      1   1     3       0

# %% [markdown]
# # 4. Find shape of dataset(Rows,Columns)

# %%
data.shape
# Out:
# (1025, 14)

# %%
print("No. of Rows", data.shape[0])
print("No. of Columns", data.shape[1])
# Out:
# No. of Rows 1025
# No. of Columns 14

# %% [markdown]
# # 5. Get information about dataset like total no. of rows, cols, datatype of cols, memory requirement

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1025 entries, 0 to 1024
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       1025 non-null   int64
#  1   sex       1025 non-null   int64
#  2   cp        1025 non-null   int64
#  3   trestbps  1025 non-null   int64
#  4   chol      1025 non-null   int64
#  5   fbs       1025 non-null   int64
#  6   restecg   1025 non-null   int64
#  7   thalach   1025 non-null   int64
#  8   exang     1025 non-null   int64
#  9   oldpeak   1025 non-null   float64
#  10  slope     1025 non-null   int64
#  11  ca        1025 non-null   int64
#  12  thal      1025 non-null   int64
#  13  target    1025 non-null   int64
# dtypes: float64(1), int64(13)
# memory usage: 112.2 KB

# %% [markdown]
# # 6. Check Null Values in dataset

# %%
data.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %% [markdown]
# # 7. Check For Duplicate Data and Drop them

# %%
duplicate_data=data.duplicated().any()
print(duplicate_data)
# Out:
# True

# %%
data=data.drop_duplicates()

# %%
data.shape
# Out:
# (302, 14)

# %%
duplicate_data=data.duplicated().any()
print(duplicate_data)
# Out:
# True

# %% [markdown]
# # 8. Get overall Statistic about dataset

# %%
data.describe()
# Out:
#              age         sex          cp    trestbps        chol         fbs  \
# count  302.00000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean    54.42053    0.682119    0.963576  131.602649  246.500000    0.149007
# std      9.04797    0.466426    1.032044   17.563394   51.753489    0.356686
# min     29.00000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     48.00000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.50000    1.000000    1.000000  130.000000  240.500000    0.000000
# 75%     61.00000    1.000000    2.000000  140.000000  274.750000    0.000000
# max     77.00000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  302.000000  302.000000  302.000000  302.000000  302.000000  302.000000
# mean     0.526490  149.569536    0.327815    1.043046    1.397351    0.718543
# ...

# %% [markdown]
# # 9. Draw Correlation Matrix

# %%
plt.figure(figsize=(17,6))
sns.heatmap(data.corr(),annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # 10. How many people have Heart disease, and how many don't have hd in the dataset.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['target'].value_counts()
# Out:
# 1    164
# 0    138
# Name: target, dtype: int64

# %%
# data['target'].value_counts().plot(kind='barh',figsize=(8,6))
# plt.ylabel("Target")
# plt.xlabel("Count")
# plt.title(" Count of target variable have heart disease")
#sns.countplot(data['target'])

# %%
sns.countplot(x='target',data=data)
plt.xticks([0,1],['Female','Male'])
plt.xticks([0,1],['Female','Male'])
# Out:
# ([<matplotlib.axis.XTick at 0x165ea20ce90>,
# ...
#  [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %% [markdown]
#  # 11. Find Count of Male & Female in the Dataset

# %%
data['sex'].value_counts()
# Out:
# 1    206
# 0     96
# Name: sex, dtype: int64

# %%
# data['sex'].value_counts().plot(kind='barh',figsize=(6,4))
# plt.ylabel("sex")
# plt.xlabel("counts")
sns.countplot(x='sex',data=data)
plt.xticks([0,1],['Female','Male'])
plt.xticks([0,1],['Female','Male'])
# Out:
# ([<matplotlib.axis.XTick at 0x165ea2abfd0>,
# ...
#  [Text(0, 0, 'Female'), Text(1, 0, 'Male')])

# %% [markdown]
# # 12. Find Gender distribution a/c to target variable.

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='sex',hue='target',data=data)
plt.xticks([0,1],['Female','Male'])
plt.legend(labels=['No-Disease','Disease'])

# %% [markdown]
# # 13.  Check age distribution in the dataset

# %%
sns.distplot(data['age'],bins=20)
plt.show()
# Out:
# C:\Users\menik\AppData\Local\Temp\ipykernel_12196\4281029158.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['age'],bins=20)

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# # 14. check chest pain type(4 values)

# %%
sns.countplot(x='cp',data=data)
plt.xticks([0,1,2,3],["typical angina","antypical angina","non-anginal pain","asymptomatic"])
plt.xticks(rotation=65)
plt.show()

# %% [markdown]
# # 15. show the chest pain distribution as per target variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='cp',hue='target',data=data)
plt.legend(labels=["No-Disease","Disease"])
plt.show()

# %% [markdown]
# # 16.Show Fasting Blood suger distribution a/c to target variable

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
sns.countplot(x='fbs',hue='target',data=data)
plt.legend(labels=["No-Diease","Disease"])
plt.show()

# %% [markdown]
# # 17.check Resting Blood Pressure Distribution

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %%
data['trestbps'].hist()
# Out:
# <Axes: >

# %% [markdown]
# # 18. compare resting blood pressure as per sex coulmn.

# %%
g=sns.FacetGrid(data,hue='sex',aspect=3)
g.map(sns.kdeplot,'trestbps',shade=True)
plt.legend(labels=['Male','Female'])
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)
# C:\ProgramData\anaconda3\Lib\site-packages\seaborn\axisgrid.py:848: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   func(*plot_args, **plot_kwargs)

# %% [markdown]
# # 19.  Show Distribution of Serum cholesterol.

# %%
data['chol'].hist()
# Out:
# <Axes: >

# %%
data.columns
# Out:
# Index(['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
#        'exang', 'oldpeak', 'slope', 'ca', 'thal', 'target'],
#       dtype='object')

# %% [markdown]
# # 20. Plot Countinuous Variables

# %%
categorical_val=[]
countinuous_val=[]

for column in data.columns:
    if data[column].nunique() <=10:
        categorical_val.append(column)     
else:
    countinuous_val.append(column)

# %%
categorical_val
# Out:
# ['sex', 'cp', 'fbs', 'restecg', 'exang', 'slope', 'ca', 'thal', 'target']

# %%
countinuous_val
# Out:
# ['target']

# %%
data.hist(countinuous_val, figsize=(14,5))
plt.tight_layout()
plt.show()
